# %%
import pandas as pd

df = pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
with open("grabacion.txt", encoding="utf-8") as f:
    data = f.read()
    
data
# Out:
# '© - Derechos Reservados: La presente obra, y todos sus contenidos, se encuentran protegidos por la normativa nacional e internacional vigente sobre propiedad Intelectual, por lo tanto su utilización parcial o total, reproducción, comunicación pública, transformación, distribución, alquiler, préstamo público e importación, total o parcial, en todo o en parte, en formato impreso o digital y en cualquier formato conocido o por conocer, se encuentran prohibidos, y solo serán lícitos en la medida en que se cuente con la autorización previa y expresa por escrito de la Fundación Universitaria Konrad Lorenz. Así mismo, de acuerdo con la normativa referente al habeas data, la utilización de la imagen de las personas, docentes o estudiantes, sin su previa autorización está expresamente prohibida. En caso de incumplirse con lo mencionado, se procederá de conformidad con los reglamentos de la Institución, sin perjuicio de las demás acciones legales aplicables. '

# %%
import json

with open("sistemas_operativos.json") as j:
    data = json.load(j)
    
# data

pd.json_normalize(data)
# Out:
#          Name          Version Install              Owner Kernel
# 0      Debian                9     apt                SPI    4.9
# 1      Ubuntu            17.10     apt          Canonical   4.13
# 2      Fedora               26     dnf            Red Hat   4.13
# 3      CentOS                7     yum            Red Hat   3.10
# 4    OpenSUSE             42.3  zypper             Novell    4.4
# 5  Arch Linux  Rolling Release  pacman                SPI   4.13
# 6      Gentoo  Rolling Release  emerge  Gentoo Foundation   4.12

# %%
import os
from zipfile import ZipFile

folder = "./astrok.zip"
with ZipFile(folder) as z:
    z.extractall()
    
for file in os.walk("./astrok"):
    print(file)
    
for root, folders, files in os.walk("./astrok"):
    print(root, folders, files)
    for f in files:
        print(f)
# Out:
# ('./astrok', [], ['Conjucio╠ün.txt', 'La muerte de las estrellas.txt', 'Perseverance.txt'])
# ./astrok [] ['Conjucio╠ün.txt', 'La muerte de las estrellas.txt', 'Perseverance.txt']
# Conjucio╠ün.txt
# La muerte de las estrellas.txt
# Perseverance.txt

# %%
# !pip install python-docx
import docx

doc = docx.Document("Colombia.docx")
parrafos = [p.text for p in doc.paragraphs]

data = []
for i,row in enumerate(doc.tables[0].rows):
    f = [cell.text for cell in row.cells]
    data.append(f)
    
pd.DataFrame(data[1:], columns= data[0])
# Out:
#                             REGION DEPARTAMENTO    MUNICIPIO
# 0  Región Eje Cafetero - Antioquia    Antioquia     Medellín
# 1  Región Eje Cafetero - Antioquia    Antioquia    Abejorral
# 2  Región Eje Cafetero - Antioquia    Antioquia     Abriaquí
# 3  Región Eje Cafetero - Antioquia    Antioquia   Alejandría
# 4  Región Eje Cafetero - Antioquia    Antioquia        Amagá
# 5  Región Eje Cafetero - Antioquia    Antioquia       Amalfi
# 6  Región Eje Cafetero - Antioquia    Antioquia        Andes
# 7  Región Eje Cafetero - Antioquia    Antioquia  Angelópolis
# 8  Región Eje Cafetero - Antioquia    Antioquia    Angostura
# 9  Región Eje Cafetero - Antioquia    Antioquia        Anorí

# %%
data = pd.read_excel("hoja.xlsx")
data.head()

data2 = pd.read_excel("hoja.xlsx", sheet_name=1)
data2.head()
# Out:
#       Hoja 2 Unnamed: 1
# 0       Días     Número
# 1      Lunes          1
# 2     Martes          2
# 3  Miércoles          3
# 4     Jueves          4

# %%
url = "https://docs.google.com/spreadsheets/d/1O8k9ZBaHSPbw_8IgE-jxmVE8FkMWimr6dZPuKhAT2hM"
url_new = url + "/gviz/tq?tqx=out:csv"

pd.read_csv(url_new)
# Out:
#      Español    English
# 0      Lunes     Monday
# 1     Martes    Tuesday
# 2  Miércoles  Wednesday
# 3     Jueves   Thursday
# 4    Viernes     Friday

# %%
# !pip install PyMuPDF
import fitz

doc = fitz.open("cien.pdf")
# doc.pageCount
# doc.metadata

page = doc.loadPage(0)
text = page.getText("text")
print(text)
# Out:
# Cien años de soledad
# Muchos años después, frente al pelotón de fusilamiento, el coronel Aureliano Buendía había de
# recordar aquella tarde remota en que su padre lo llevó a conocer el hielo. Macondo era entonces
# una aldea de veinte casas de barro y cañabrava construidas a la orilla de un río de aguas diáfanas
# que se precipitaban por un lecho de piedras pulidas, blancas y enormes como huevos
# prehistóricos. El mundo era tan reciente, que muchas cosas carecían de nombre, y para
# mencionarlas había que señalarías con el dedo. Todos los años, por el mes de marzo, una familia
# de gitanos desarrapados plantaba su carpa cerca de la aldea, y con un grande alboroto de pitos y
# timbales daban a conocer los nuevos inventos. Primero llevaron el imán. Un gitano corpulento, de
# barba montaraz y manos de gorrión, que se presentó con el nombre de Melquiades, hizo una
# truculenta demostración pública de lo que él mismo llamaba la octava maravilla de los sabios
# ...

# %%
# !pip install pytesseract
# https://github.com/UB-Mannheim/tesseract/wiki
import pytesseract
from pytesseract import image_to_string
from PIL import Image

pytesseract.pytesseract.tesseract_cmd = "C:\\Program Files\\Tesseract-OCR\\tesseract.exe"  ### WINDOWS
texto = image_to_string(Image.open("demo.jpg"))
print(texto)
# Out:
#
#
# function_name = “getGmailemails”
# request = {"function": function_name}
#
# response = GetClient().scripts().run(body-request, scriptId-script_id) .execute()
# print (response)
#
#
#
#
#
# {'done’: True, ‘response’: {"@type’: ‘type.googleapis. com/google. apps. script.v1.xecutionResponse’}}
