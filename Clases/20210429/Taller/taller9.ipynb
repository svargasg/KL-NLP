# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguaje Natural
#
# ## Taller #9: Modelado de temas
# `Fecha de entrega: Mayo 6, 2021. (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`

# %%
import re
import pandas as pd 
from pprint import pprint

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

import pyLDAvis.gensim_models
from gensim.models import LdaModel
from gensim.corpora import Dictionary

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# c:\Users\Home\Documents\Repositorios\KL-Natural_Language_Processing\env\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# c:\Users\Home\Documents\Repositorios\KL-Natural_Language_Processing\env\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# Cargar datos
path = 'reviews_vidjew_es.csv'
data = pd.read_csv(path)
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category
# 0       es          jewelry
# 1       es      video_games
# 2       es      video_games
# 3       es      video_games
# 4       es      video_games

# %% [markdown]
# ###  `[12 pts]` Punto 1: Hacer pre-procesamiento del texto

# %%
def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d]+", " ", texto)
    texto = [palabra for palabra in texto.split() if palabra not in stopwords]
    return texto 

data['pp'] = data['review_body'].apply(lambda texto: pre_procesado(texto))

data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category                                                 pp
# 0       es          jewelry        [buen, buena, calidad, buena, presentación]
# 1       es      video_games  [producto, perfecto, salir, casa, nintendo, sw...
# 2       es      video_games  [funciona, nintendo, switch, forma, emparejarl...
# 3       es      video_games  [recomendado, utilizo, pc, dan, ningún, proble...
# 4       es      video_games  [cable, funciona, bien, podria, ser, mas, larg...

# %% [markdown]
# ###  `[10 pts]` Punto 2: Modelo de LDA

# %%
# Crear una represantación de los documentos en forma de diccionario
dictionary = Dictionary(data['pp'].values)

# Filtrar palabras muy frecuentes o infrecuentes
dictionary.filter_extremes(no_below=5, no_above=0.5) 

# Corpus
corpus = [dictionary.doc2bow(text) for text in data['pp'].values]

# Entrenar el modelo
model = LdaModel(corpus = corpus, id2word = dictionary, num_topics = 6, passes=10)

# %% [markdown]
# ###  `[25 pts]` Punto 3: Visualización de LDA

# %%
lda_display = pyLDAvis.gensim_models.prepare(model, corpus, dictionary, sort_topics=True)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el101323164839265480189241179"></div>
# <script type="text/javascript">
#
# var ldavis_el101323164839265480189241179_data = {"mdsDat": {"x": [-0.1168085626349569, -0.06703646456403839, -0.03831374093389443, -0.02083144048371035, 0.0406087571967295, 0.20238145141987082], "y": [0.05854465549022282, 0.10374798219941546, -0.17729440519695755, -0.04773185531908449, 0.041353343934144755, 0.02138027889225896], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [20.09371375751294, 18.95015785268358, 16.8734425617641, 15.332553880567746, 14.665969888407544, 14.084162059064088]}, "tinfo": {"Term": ["juego", "d\u00eda", "bien", "producto", "bonito", "buena", "buen", "foto", "llegado", "queda", "vendedor", "bonitos", "nunca", "plata", "color", "bueno", "caja", "amazon", "parece", "bonita", "pendientes", "pulsera", "jugar", "todas", "cumple", "entregado", "calidad", "puede", "gustado", "pedir", "botones", "pantalla", "pc", "cabe", "divertido", "apenas", "cargador", "mandos", "ni\u00f1os", "entra", "cable", "igualmente", "cerrar", "carga", "conectar", "mientras", "cambiar", "primera", "encajan", "f\u00e1cilmente", "modo", "quieres", "gustan", "sitio", "largo", "pulseras", "much\u00edsimo", "grande", "caso", "puedes", "original", "quedan", "juegos", "switch", "bien", "va", "mando", "puede", "jugar", "si", "ps", "bastante", "mal", "cierre", "funda", "solo", "estrellas", "mas", "pena", "dos", "consola", "calidad", "ser", "esperaba", "juego", "viene", "perfecto", "fan", "ingles", "pocas", "ah\u00ed", "edici\u00f3n", "espa\u00f1ol", "sonido", "gr\u00e1ficos", "bot\u00f3n", "a\u00f1os", "entretenido", "aceptable", "juego", "historia", "piedra", "buena", "poca", "jugabilidad", "luces", "presentaci\u00f3n", "disco", "pro", "peque\u00f1a", "opci\u00f3n", "italiano", "opinar", "super", "demasiado", "ruido", "poder", "horas", "mala", "calidad", "jugar", "ps", "precio", "viene", "aunque", "recomiendo", "mejor", "funciona", "pena", "decir", "si", "parece", "buen", "caja", "momento", "dos", "ser", "perfecto", "bastante", "regalo", "consola", "as\u00ed", "color", "pandora", "fino", "dorado", "rosa", "corta", "fea", "rompi\u00f3", "encantada", "fina", "bonita", "preciosos", "elegantes", "tiendas", "queda", "medida", "cajita", "negro", "puestos", "juegazo", "encant\u00f3", "elegante", "plata", "pueden", "bolsita", "adapta", "bolsa", "brillo", "bonito", "contenta", "pulsera", "bonitos", "tal", "gustado", "bien", "cadena", "regalo", "llego", "collar", "q", "vez", "precio", "foto", "tiempo", "calidad", "peque\u00f1o", "perfectamente", "perfecto", "aunque", "producto", "recomiendo", "compra", "si", "compr\u00e9", "realidad", "one", "ven", "baja", "espa\u00f1ola", "fatal", "xbox", "pedir", "cuello", "descripci\u00f3n", "ningun", "dio", "rompio", "tra\u00eda", "versi\u00f3n", "colgante", "adecuado", "exactamente", "volver\u00eda", "resulta", "ve", "contento", "fotos", "gust\u00f3", "general", "foto", "hija", "interesante", "rapidez", "parecido", "parece", "pedido", "buen", "roto", "igual", "mas", "precio", "bonito", "comprar", "material", "puede", "producto", "peque\u00f1o", "calidad", "tan", "lleg\u00f3", "regalo", "si", "tal", "bien", "as\u00ed", "juego", "funciona", "alg\u00fan", "media", "funci\u00f3n", "todas", "mes", "expectativas", "ir", "detalle", "bueno", "cumple", "medio", "funcionar", "devolver", "esperando", "pendientes", "veces", "devolverlo", "\u00fanica", "llevo", "c\u00f3modos", "perlas", "devoluci\u00f3n", "pronto", "debido", "fecha", "quiz\u00e1s", "poner", "siempre", "peque\u00f1os", "despu\u00e9s", "amazon", "perfecto", "bonitos", "tama\u00f1o", "compra", "producto", "as\u00ed", "buen", "calidad", "precio", "lleg\u00f3", "pl\u00e1stico", "servicio", "tiempo", "dos", "mando", "problema", "caja", "bien", "si", "gustado", "vendedor", "previsto", "entregado", "precioso", "peor", "nunca", "seg\u00fan", "d\u00eda", "prime", "decepcionado", "repartidor", "recibido", "cosas", "falta", "dicen", "rota", "certificado", "negra", "ni\u00f1as", "luego", "llega", "dice", "devuelto", "llegado", "cosa", "tienda", "di ...

# %% [markdown]
# ###  `[3 pts]` Preguntas
#
# - ¿Qué conclusiones puede sacar de los resultados de los últimos tres talleres, usando diferentes modelos pero los mismos datos?
